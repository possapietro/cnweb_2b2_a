# %% [markdown]
# <a href="https://colab.research.google.com/github/possapietro/cnweb_2b2_a/blob/main/cinematica-aula0604.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fórmula da velocidade
# fonte: [https://www.todamateria.com.br/formulas-de-cinematica/]

# %%
def calculaVelMedia(deltaS, deltaT):
  velMedia = (deltaS/deltaT)
  return velMedia

# %% [markdown]
# ## Teste Serviço Nuvem: Velocidade Média

# %%
print("Vm=", calculaVelMedia(30, 15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_22080/2325260437.py in <cell line: 0>()
# ----> 1 print("Vm=", calculaVelMedia(30, 15))
#
# NameError: name 'calculaVelMedia' is not defined

# %% [markdown]
# # Fórmula da aceleração

# %%
def aceleracaomedia(tempo, velocidade):
  velmedia = (velocidade/tempo)
  return velmedia

# %%
print("Am", aceleracaomedia(30, 15))
# Out:
# Am 2.0

# %% [markdown]
# # Fórmulas do Movimento Uniforme (MU)

# %% [markdown]
# # Função horária do deslocamento

# %%
def calculaDesloc(inicialS, deltaT, v):
  d = inicialS + (v*deltaT)
  return d

# %% [markdown]
# ## Testes de Função : Horária de Deslocamento

# %%
print("Deslocamento= ",calculaDesloc(0, 15, 30))
# Out:
# Deslocamento=  450

# %% [markdown]
# # Fórmulas do Movimento Uniformemente Variado (MUV)

# %% [markdown]
# # Nova seção

# %% [markdown]
# ## Função horária da velocidade

# %% [markdown]
# ## Função horária da posição

# %%
def calVelocidadeHoraria(vInicial, aceL, tempo):
  vh = vInicial + (acel * tempo)
  return

# %% [markdown]
# ## teste de aceleração horaria

# %%
def calcularPosicaoMUV(posicao_inicial, velocidade_inicial, aceleracao, tempo):
  posicao_final = posicao_inicial + (velocidade_inicial * tempo) + (0.5 * aceleracao * (tempo ** 2))
  return posicao_final

# %%
print("Função horária da posição:", calcularPosicaoMUV(15,4,3,5))
# Out:
# Função horária da posição: 72.5

# %% [markdown]
# # Equação de Torricelli

# %%
import math

def caltoricelli(vZero, acel, des):
  t=2*acel*des
  v=vZero+t
  res =round(math.sqrt(v), 2)
  return res

# %% [markdown]
# ## teste de torricelli

# %%
print("calculo de torricelli:",caltoricelli(0,3,8))
# Out:
# calculo de torricelli: 6.93

# %% [markdown]
# # Fórmula do movimento vertical
